# %%
import requests
from bs4 import BeautifulSoup

def capturar_texto(url):
    resp = requests.get(url)
    resp.encoding = "utf-8"   # força UTF-8
    soup = BeautifulSoup(resp.text, "html.parser")
    texto = soup.get_text(separator="\n")
    return texto

if __name__ == "__main__":
    url = "https://apps.univesp.br/manual-do-aluno/"
    conteudo = capturar_texto(url)
    print(conteudo)
# Out:
# Univesp | Manual do Aluno
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Manual do Aluno
#
#
#
#
#
#
#
#
#
#
# share
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Início
#
#
# Sobre os cursos
#
#
# Normas acadêmicas
#
#
# Calendário acadêmico e Provas
#
#
# Avaliação - graduação
#
#
# Ambiente Virtual de Aprendizagem
#
#
# Projeto Integrador
#
#
# TCC
#
#
# Estágio
#
#
# Atividades Práticas Profissionais – APP
#
#
# Normalização de Trabalhos Acadêmicos
#
#
# Netiqueta
#
#
# Equipe Univesp
#
#
# Acessibilidade e Inclusão Univesp
#
#
# Canais de comunicação
#
#
# Tutoriais
#
#
# Oferta de Disciplinas e Matrícula
#
#
# Aproveitamento
#
#
# Suas videoaulas na TV
#
#
# Colação de Grau e Diploma
#
#
# ENADE
#
#
# Pós-Graduação
#
#
# CPA
#
#
#
#
#
#
# close
#
#
#
#
#
#
# Manual do Aluno
#
#
# Início
#
#
# Olá!
#
#
# Este é um guia que irá ajudar a
# esclarecer as principais dúvidas
#  que você possa ter durante o curso. Antes de enviar uma dúvida para o suporte, verifique este documento, que é regularmente atualizado com as respostas aos
#           questionamentos mais comuns dos estudantes.
#
#
# Esperamos que seja um material útil para você. Consulte-o sempre que precisar.
#
#
#
#
#
#
#
#
# Sobre os cursos
#
#
# A Univesp oferece atualmente nove cursos de graduação: Ciência de Dados, Tecnologia da Informação, Engenharia de Computação, Pedagogia, Matemática, Letras com habilitação em Língua Portuguesa, Administração, Tecnologia em Processos Gerenciais e Engenharia de Produção. Também  mantém estudantes matriculados no curso de Tecnologia em Gestão Pública, em parceria com o Centro Paula Souza.
#
#
# As disciplinas da graduação são bimestrais, com conteúdos divididos em 7 ou 8 módulos, liberados semanalmente no Ambiente Virtual de Aprendizagem (AVA). São cursadas em média três disciplinas por bimestre.
#
#
# A duração ideal dos cursos é de 3 anos para Tecnólogo, 4 para as Licenciaturas e 5 para as Engenharias. Cada curso é regido por um Projeto Pedagógico de Curso (PPC). Conheça os PPCs dos cursos Univesp:
#
#
#
#
#
#
#
#
# Engenharia de Computação
#
#
# PPC
#
#
# 2017
#
#
# 2020
#
#
# 2024
#
#
# 2025
#
#
#
#
# Matriz Curricular
#
#
# 2017
#
#
# 2020
#
#
# 2024
#
#
#
#
#
#
#
#
# Engenharia de Produção
#
#
# PPC
#
#
# 2017
#
#
# 2022
#
#
# Matriz Curricular
#
#
# 2017
#
#
# 2022
#
#
#
#
#
#
#
#
# Letras – Habilitação em Língua Portuguesa
#
#
# PPC
#
#
# 2019
#
#
# 2020
#
#
# 2023
#
#
# Matriz Curricular
#
#
# 2019
#
#
# 2020
#
#
#
#
#
#
#
#
# Licenciatura em Matemática
#
#
# PPC
#
#
# 2017
#
#
# 2018
#
#
# 2019
#
#
# 2020
#
#
# 2023
#
#
#
#
# Matriz Curricular
#
#
# 2014
#
#
# 2017
#
#
# 2018
#
#
# 2019
#
#
# 2020
#
#
# 2023
#
#
#
#
#
#
#
#
# Pedagogia
#
#
# PPC
#
#
# 2017
#
#
# 2018
#
#
# 2019
#
#
# 2020
#
#
# 2023
#
#
#
#
# Matriz Curricular
#
#
# 2017
#
#
# 2018
#
#
# 2019
#
#
# 2020
#
#
# 2023
#
#
#
#
#
#
#
#
# Tecnólogo em Gestão Pública
#  (em parceria com a FATEC)
#
#
# PPC
#
#
#
#               Matriz Curricular
#
#
#
#
#
#
#
#
#
# Bacharelado em Tecnologia da Informação
#
#
# PPC
#
#
# 2020
#
#
# 2024
#
#
# 2025
#
#
# Matriz Curricular
#
#
# 2020
#
#
# 2024
#
#
#
#
#
#
#
#
# Bacharelado em Ciência de Dados
#
#
# PPC
#
#
# 2020
#
#
# 2024
#
#
# 2025
#
#
# Matriz Curricular
#
#
# 2020
#
#
# 2024
#
#
#
#
#
#
#
#
# Bacharelado em Administração
#
#
# PPC
#
#
# 2022
#
#
# Matriz Curricular
#
#
# 2022
#
#
#
#
#
#
#
#
# Tecnologia em Processos Gerenciais
#
#
# PPC
#
#
# 2022
#
#
# Matriz Curricular
#
#
# 2022
#
#
#
#
#
#
#
#
#
#
#
#
# Normas Acadêmicas
#
#
# É fundamental que você fique a par dos procedimentos acadêmicos e administrativos que precisam ser seguidos durante o tempo em que estiver matriculado na Univesp.
#
#
#
#           No AVA, no menu lateral em todas as disciplinas, você encontra o link para as
# Normas
#             Acadêmicas
# .
#
#
#
#
#
#
#
#
#
# Calendário Acadêmico e Provas
#
#
#
#           Na Educação a Distância, dois aspectos importantes na atuação de um estudante são a autonomia e o gerenciamento do próprio processo de aprendizagem. O que você acha de organizar sua agenda de estudos iniciando pelo Calendário Acadêmico?
#           Acesse:
#
#
#
# 2025
#
#
#
#
# Calendário de provas
#
#
#
#
# 2025
#
#
#
#
# Calendário Acadêmico
#
#
#
#
#
#
#
#
#
#
# Avaliação - graduação
#
#
# A carga horária de cada curso da Univesp está distribuída em disciplinas bimestrais regulares, Projeto Integrador, Estágio Obrigatório e Trabalho de Conclusão de Curso. A integralização das horas se dá por diferentes instrumentos
#           avaliativos.
#
#
# Disciplinas bimestrais regulares
#
#
# Nas
# disciplinas bimestrais regulares
# , existem três instrumentos independentes e articulados para verificação da aprendizagem das habilidades e conteúdos propostos:
#
#
#
#
# 40% da nota é composta por
# atividades avaliativas
#  propostas ao longo do bimestre e realizadas no próprio AVA.
#
#
# Os outros 60% são da
# prova presencial
# , realizada ao fim do bimestre no polo, conforme o Calendário Acadêmico de cada curso e o horário da turma. No AVA, os professores informam, na última semana da disciplina, se há necessidade de levar algum material específico para a realização da prova.
#
#
#
# Estudantes que não obtiverem a média necessária para a aprovação poderão realizar o
# exame final
#  da disciplina.
#
#
#
#
# Observação:
#  A pontuação do exame varia de 0 (zero) a 10 (dez). Para calcular a média final após a prova de exame, soma-se a nota de exame à média obtida anteriormente (Média final na disciplina no bimestre, composta pela prova regular e atividades realizadas no AVA); esse total é dividido por dois e o resultado será a média final do aluno na respectiva disciplina, após exame.
#
#
# Conheça termos e alguns detalhes sobre sua prova:
# Glossário de provas
#
#
# Projetos Integradores
#
#
# Nos
# Projetos Integradores
# , existem dois instrumentos articulados para verificação da aprendizagem das habilidades e conteúdos propostos:
#
#
#
#
# 40% da nota final
#  corresponde à integração da entrega dos planos de ação e do relatório parcial do Projeto Integrador.
#
#
# 60% da nota final
#  corresponde ao relatório final e ao vídeo, de acordo com uma estrutura e modelo fornecidos pela Univesp. A correção do relatório final está condicionada à entrega do vídeo de apresentação do Projeto
#             Integrador.
#
#
#
#
# Você encontra todas as orientações essenciais no
# Regulamento para o Projeto Integrador
#  no AVA, no menu lateral das disciplinas.
#
#
# Observação:
#  O Projeto Integrador do Curso Superior de Tecnologia em Gestão Pública será avaliado da seguinte maneira: Atividade final (50%) + Atividades parciais (50%). As entregas das semanas 3, 5 e 6 não são avaliativas.
#
#
#
# Estágio
#
#
# A validação das horas dos
# Estágios Obrigatórios
#  se dá ao final de um processo de acompanhamento composto por:
#
#
#
#
# Formalização do estágio
# , com a entrega dentro do prazo do Termo de Compromisso, celebrado entre estagiário, parte concedente do estágio e Univesp, e do Plano de Atividades do Estágio Obrigatório.
#
#
# Acompanhamento do estágio
# , com a entrega da grade de frequência.
#
#
# Entrega do
# Relatório Final de Estágio
# , comprovando a finalização do estágio na parte concedente e o cumprimento da carga horária prevista, validada pelo supervisor da parte concedente.
#
#
#
#
# A validação do Estágio é registrada e expressa pelo parecer: Cumpriu ou Não Cumpriu.
#
#
# Você encontra todas as orientações e documentos essenciais de estágio na
# Sala de Documentos de Estágio e APP
# .
#
#
# Trabalhos de Conclusão de Curso
#
#
# Nos
# Trabalhos de Conclusão de Curso
# , existem dois instrumentos articulados para verificação da aprendizagem das habilidades e conteúdos propostos:
#
#
#
#
# A avaliação da disciplina é formativa (entregas parciais) e somativa (TCC final). Essas entregas parciais serão direcionadas por roteiros de aprendizagem. O peso total dessas entregas é de 30% da nota e a
#             banca define 70% da nota final.
#
#
#
#
# Você encontra todas as orientações essenciais no
# Regulamento do Trabalho de Conclusão de Curso
#  no AVA, no menu lateral das disciplinas.
#
#
# Instrução Normativa - Provas
#
#
# Veja abaixo a instrução normativa que dispõe sobre as atividades presenciais (provas), para os cursos de Graduação da Universidade Virtual do Estado de São Paulo – Univesp.
#
#
# Instrução normativa
#
#
# Publicação no DOE (Diário Oficial do Estado)
#
#
#
#
#
#
#
#
# Ambiente Virtual de Aprendizagem (AVA)
#
#
#
#
#
#           Nosso Ambiente Virtual de Aprendizagem está organizado de forma dinâmica e intuitiva para que você possa navegar pelos conteúdos oferecidos de maneira prática e eficiente.
#
#
#
#
#           Todas as disciplinas estão organizadas em módulos liberados semanalmente, e contam com um professor autor/formador que é responsável pelo conteúdo e pelas atividades.
#
#
#
#
#           Ao entrar na disciplina, você encontrará a foto e o currículo do professor responsável pela oferta atual, o plano de ensino e os temas que serão trabalhados em cada uma das semanas.
#
#
#
#
#           Ao clicar no tema da semana, você é direcionado para a página seguinte, com todos os materiais que compõem o roteiro de aprendizagem do módulo (videoaulas, textos para leitura, exercícios de apoio, atividades avaliativas e fóruns).
#
#
#
#
#           Os conteúdos são divididos em materiais-base e materiais de apoio.
#
#
#
#
#           Os
# materiais-base
#  são de consulta obrigatória. As atividades avaliativas e as questões que compõem as provas presenciais estão fundamentadas nos conceitos apresentados nesses materiais.
#
#
#
#
#           Já os
# materiais de apoio
#  são muito importantes para que você possa complementar, aprofundar e ampliar os conceitos que está aprendendo. Entretanto, não são obrigatórios e, por isso, não são diretamente cobrados nas avaliações.
#
#
#
# Organização dos Fóruns
#
#
#
#           No roteiro de aprendizagem de cada semana, está prevista a possibilidade de interação entre você e seus colegas: são os fóruns.
#
#           Há duas modalidades de fóruns:
#
#
#
# Fórum de dúvidas
#  -
# presente em todas as semanas da disciplina
# , é um espaço para você apresentar as dúvidas que apareceram ao longo da semana, relacionadas com o tema estudado e os materiais disponíveis.
#
#
# Fórum temático
#  -
# proposto pelo professor responsável
# , aparece eventualmente. É criado quando o professor julgar importante a troca, entre os alunos, de experiências e conhecimentos
# a respeito de um assunto
#               específico
# .
#
#
#
#         A partir do primeiro semestre de 2019, os fóruns deixam de ser divididos por polos, e passam a ser organizados por grupos de 50 alunos. Essa nova forma vai permitir uma interação mais construtiva, com intervenções personalizadas por parte
#         do responsável pela disciplina.
#
#
#
#
#
#
#
# Projeto Integrador
#
#
#
#           O Projeto Integrador é uma atividade semestral que objetiva articular os conhecimentos adquiridos no curso em um
# contexto prático
# . No PI é desenvolvido um projeto, um novo produto ou intervenção, por meio de trabalho em equipe.
#
#           Consulte a
# matriz curricular
#  do seu curso para saber em quais semestres você terá Projeto Integrador. E acesse também o
# Regulamento para o Projeto Integrador
# .
#
#
#
# Também preparamos um documento de Orientações para o bom desenvolvimento do PI: clique
# aqui
#  caso
#           você seja do curso de Gestão Pública, ou
# aqui
#  se for dos demais cursos.
#
#
# Inspire-se
# , acesse nosso
# repositório de PI
#  e veja os trabalhos anteriores de nossos alunos
#
#
#
#
#
#
#
#
#
#
# TCC
#
#
#
#           Estarão aptos a cursarem o TCC, os alunos que tiverem concluído, no mínimo, 62,5% da carga horária total do curso, exceto para o curso de Tecnólogo em Gestão Pública. Além dos materiais disponibilizados pelo professor da disciplina, os
#           estudantes terão a orientação de
#           um mediador ou facilitador de aprendizagem durante a elaboração e a execução de seu projeto de pesquisa. Ao fim do processo, os estudantes devem entregar o
# trabalho por escrito
#  e também apresentá-lo perante uma
# banca
# .
#
#
#
# O regulamento completo do TCC pode ser conferido neste
# link
# .
#
#
# Inspire-se
# , acesse nosso
# repositório de TCC
#  e veja os trabalhos anteriores de nossos alunos
#
#
#
#
#
#
#
#
# Estágio
#
#
# Existem duas modalidades de estágio:
# obrigatório
#  e
# não obrigatório
# .
#
#
#
#
#
#               O
# estágio curricular obrigatório
#  será desenvolvido conforme previsto na matriz curricular dos cursos. Ele é determinado por lei, e visa preparar o estudante regular para o trabalho.
#
#
#
#
#               Já o
# estágio não obrigatório
#  é o estágio que pode ser realizado pelo aluno, mas não é componente da matriz curricular. As horas cumpridas nesse estágio não são computadas para o estágio obrigatório e nem para a integralização do curso.
#
#
#
#
#
#
#
# TOP 7 Alertas de estágio não obrigatório:
#  Acesse
# aqui
# .
#
#
#
#
#
#
# Documentos e informações
#
#
# Acesse a
# Sala de Documentos de Estágio e APP
#  para consultar regulamentos, orientações, modelos e formulários relacionados ao tema.
#
#
# Você também pode consultar as dúvidas mais frequentes no
#
#               FAQ
#  preparado pela Univesp.
#
#
#
#
#
#
# Alunos das Licenciaturas
# , acesse
# aqui
#  a lista de diretorias de ensino para realizar os estágios.
#
#
#
#
#
#
#
#
#
#
# Atividades Práticas Profissionais (APP)
#
#
# Os alunos do
# Eixo da Computação
#  (Bacharelado em Tecnologia da Informação, Ciência de dados e Engenharia da Computação), que ingressaram na UNIVESP a partir de 2020, devem completar
# 200h
#  de componente curricular sobre práticas profissionais. Os alunos do curso de
# Bacharelado em Administração
#  devem completar
# 150h
# . As modalidades de Atividades Práticas Profissionais disponíveis para o cumprimento dessa carga horária são:
#
#
#
#
# Estágio Curricular:
#  em empresas ou órgãos públicos e privados das mais diversas áreas, sob supervisão de um profissional da área do curso com projeto alinhado ao desenvolvimento pedagógico;
#
#
# Certificações Extracurriculares:
#  certificados de cursos realizados por empresas ou entidades da área do curso, presenciais ou online, que leve a complementação dos conhecimentos adquiridos;
#
#
# Atividades Práticas em Trabalhos Voluntários:
#  atividades na área do curso realizadas como trabalhos voluntários, desde que relacionadas com a área de formação.
#
#
#
#
# Essas atividades são de grande relevância para a formação profissional e para o desenvolvimento do senso de cidadania dos alunos da UNIVESP.
#
#
#
#
# Documentos e informações
#
#
# As regras para cada modalidade podem ser consultadas na
# Sala de Documentos de Estágio e APP
# , ao selecionar algum curso do Eixo da Computação.
#
#
#
#
#
#
#
#
#
#
# Normalização de Trabalhos Acadêmicos
#
#
#
#           Na produção de trabalhos acadêmicos, como relatórios de PI ou TCC, é preciso observar determinadas normas a respeito de formatação e apresentação dos textos.
#
#
#
#
#           A Univesp possui um manual específico para isso: o
# Manual de normalização de trabalhos acadêmicos
# . Você pode
#           salvá-lo para consultá-lo facilmente sempre que necessário.
#
#
#
#
#
#
#
#
#
# Netiqueta
#
#
#
#           Você já ouviu falar em netiqueta?
#
#
#
#
#           Trata-se da “etiqueta virtual”, ou seja, de comportamentos que devemos observar para garantir boas relações e interações em ambientes virtuais. Para saber mais sobre netiqueta, acesse o vídeo abaixo:
#
#
#
#
#
#
#
#
#
#
#
#
#
# Há também boas práticas para participar de lives. Para que tudo corra bem, é fundamental um bom
# planejamento das atividades
# , manter a
# interatividade
#  durante a sessão e habilidade na
# resolução de
#             conflitos
# . Conheça algumas boas práticas para lives!
#
#
#
#
# Se conecte em um local silencioso para que você possa se concentrar e fazer perguntas.
#
#
# Entre na live com câmera e microfones desligados para que os eventuais ruídos não atrapalhem. Mas, quando achar necessário, participe sem medo de se expor. Abra o microfone e a câmera quando desejar fazer uma pergunta.
#
#
# Pesquise termos que não entendeu na disciplina. Traga contribuições para a Live.
#
#
# Leia os materiais, anote reflexões, envie por e-mail, se manifeste nos fóruns para que assim a live seja de fato produtiva e baseada naquilo que você realmente busca solucionar.
#
#
# Antes da live, leia e faça fichamentos dos textos. Estude antes o conteúdo.
#
#
# Apresente-se no Chat.
#
#
# Participe das discussões com os colegas.
#
#
# Fale e questione, além de escutar. Os facilitadores precisam do feedback e interação para direcionar o preparo do material das lives e para conseguir atender a sua expectativa.
#
#
# Compartilhe o espaço de dúvidas com os demais colegas - você não será o único com dúvidas.
#
#
# As lives geralmente têm muitas pessoas participando. Não se esqueça de ser breve e proporcionar a oportunidade para que outro aluno também fale e tire suas dúvidas.
#
#
# Não espere todas as respostas do facilitador. Seja proativo.
#
#
# Respeito mútuo - trate todos sempre com muito respeito e cordialidade.
#
#
#
#
#
#
#
#
#
#
# Equipe Univesp: Atribuições
#
#
#
#           A Univesp é composta por centenas de pessoas, em diversas funções, trabalhando diariamente para possibilitar e aperfeiçoar a sua aprendizagem. Conheça alguns dos atores desse processo:
#
#
#
# Supervisor
#
#
#
#           Apoia o desenvolvimento das atividades de caráter pedagógico, orienta e coordena as atividades dos mediadores e facilitadores.
#
#
#
# Orientador de Polo
#
#
#
#           Acompanha as atividades no polo e media as relações entre Univesp, polos, estudantes, facilitadores e mediadores. Também dá suporte a alguns serviços de secretaria acadêmica.
#
#
#
# SRA
#
#
#
#           A Secretaria de Registro Acadêmico é um órgão técnico-acadêmico-administrativo, responsável pelo registro e controle das informações pertinentes aos dados acadêmicos dos cursos e dos estudantes – por exemplo, diplomas e atestados de
#           matrícula.
#
#
#
# Autor
#
#
#
#           É o
# professor da disciplina
# , responsável pelo acompanhamento e escolha dos materiais que deverão compor os conteúdos de cada módulo do bimestre. Também elabora as atividades e gabaritos.
#
#
#
# Produção de conteúdo
#
#
#
#           Orienta, coordena e produz, em conjunto com os autores e demais personagens do processo educacional, os conteúdos a serem ofertados aos estudantes, definindo a linha pedagógica de cada curso e validando todos os materiais, atividades e
#           recursos didáticos.
#
#
#
#
#
#
#
# Acessibilidade e Inclusão Univesp
#
#
# Olá, estudante!
#
#
# Abaixo você pode apreciar e explorar alguns documentos e recursos que são fundamentais para a temática de acessibilidade e inclusão na Univesp.
#
#
# 1 -
#
# Política geral de acessibilidade e inclusão
#  e a
# portaria que institui a Comissão de acessibilidade e inclusão da Univesp
#
#
# 2 -
#
# Cartilha de boas práticas para a inclusão das pessoas com deficiência no ensino superior
#
#
#
# 3 -
#
# Programa Libras para todos
#  você tem acesso direto para o Programa Libras para todos. Caso você tenha interesse aproveite este programa para conhecer e aprender um pouco mais sobre a Libras.
#
#
# 4 -
#  Ferramentas para apoio à aprendizagem:
#
#
#
#
# Aplicativo VLibras
#
#
# Leitor de Tela NVDA
#
#
# Biblioteca Digital - BibliON
#
#
# REA - Recursos Educacionais Abertos
#
#
# Tecnologia Assistiva
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Canais de Comunicação
#
#
#
#           Em uma universidade virtual, você pode ficar confuso quanto a quem deve procurar em determinados casos. Mas fique tranquilo: para cada necessidade, há um canal específico descrito abaixo.
#
#
#
#
#
#
#             Para aspectos acadêmico-pedagógicos, você deve procurar o
# responsável pela mediação da disciplina
# , ou seja, tutor, mediador ou facilitador de aprendizagem.
#
#
# Exemplos:
#  dúvidas sobre os conteúdos das disciplinas, encontros no Polo, Projeto Integrador, dúvidas sobre o AVA etc.
#
#
#
#
#             Para aspectos acadêmico-administrativos, você deve buscar o
# Orientador de Polo
# .
#
#
# Exemplos:
#  emissão de declarações, atestados, trancamentos de matrícula.
#
#
#
#
#             Para atendimento virtual, acesse o
# Sistema de Atendimento Eletrônico (SAE)
# .
#
#
# Exemplos:
#  suporte aos Sistemas Univesp, sugestões, reclamações, informações e elogios.
#
#
#
#
#             Para aspectos relativos a datas e eventos acadêmicos, consulte o
# Calendário Acadêmico
# .
#
#
# Exemplos:
#  datas de avaliações presenciais, rematrículas etc. O calendário fica disponível no menu das disciplinas no Ambiente Virtual de Aprendizagem.
#
#
#
#
#             Para informações acadêmicas diversas, fique atento aos Comunicados enviados por
# e-mail
#  e
# AVA
# .
#
#
# Exemplos:
#  informações sobre aproveitamento de estudos, DPs e lembretes de prazos.
#
#
#
#
#
#
#
#
#
#
#
# Tutoriais
#
#
#
#           Na Educação a Distância (EaD) é fundamental que você saiba navegar nas principais ferramentas que são utilizadas como meios de acesso aos conteúdos propostos nas disciplinas, tais como o
# Ambiente Virtual de Aprendizagem
#             (AVA)
#  e as
# bibliotecas digitais
# . Também é importante entender como utilizar o Portal do Aluno, sobretudo porque é por meio dele que você realiza importantes ações acadêmicas.
#
#
#
#
#           Em vista disso, preparamos um site com diversos tutoriais com o objetivo de esclarecer eventuais dúvidas para facilitar a sua interação com esses e outros ambientes que serão muito úteis durante a sua graduação.
#
#
#
#
#           Você pode visitá-lo neste
# link
# .
#
#
#
#
#
#
#
#
#
# Oferta de disciplinas e Matrícula
#
#
# Atualmente, a Univesp oferta disciplinas nas seguintes modalidades:
#
#
#
#
#
#
#
#
# Disciplinas regulares
#
#
# Disciplinas ofertadas conforme a matriz do curso, para alunos que estão seguindo a grade normalmente ou ficaram em dependência na mesma disciplina.
#
#
#
#
#
#
# Disciplinas regulares equivalentes
#
#
# Oferta especial para alunos em dependência, servindo como substituta (por conteúdo ou por carga horária) de uma disciplina regular que não está sendo ofertada.
#
#
#
#
#
#
# Disciplinas regulares eletivas
#
#
# Nesta modalidade, prevista atualmente nos cursos de Ciência de Dados e Engenharia de Computação com ingresso a partir de 2020, o aluno pode escolher, a partir de uma lista disponibilizada pela Univesp, qual disciplina quer cursar para cumprir a carga horaria prevista para eletivas no projeto pedagógico do ser curso.
#
#
#
#
#
#
# ATENÇÃO:
#  Todas estas modalidades possuem atividades avaliativas, prova regular e exame. Fique atento aos prazos de suas atividades.
#
#
#
#
#
#
#
#
#
#
# Oferta de disciplinas
#
#
# Confira as disciplinas com previsão de oferta e as informações de matrícula abaixo:
#
#
#
#
# 1º Semestre de 2025
#
#
# De 9 a 15 de janeiro de 2025, no
# Portal do Aluno
# , acesse o menu “Matrícula”, “Matrícula/Renovação”, verifique as disciplinas que você deverá cursar e confirme sua matrícula. As disciplinas disponíveis estão nos links abaixo:
#
#
#
#
#
#
# Oferta de disciplinas regulares
#  Para todos os cursos e turmas
#
#
# As equivalências disponibilizadas são válidas para esta oferta, podendo sofrer alterações nos próximos semestres.
#
#
# O aluno deve conferir as disciplinas incluídas em sua matrícula e, em caso de qualquer divergência, deve entrar em contato com o SAE durante o período de matrículas.
#
#
#
#
#
#
#
#
#  Oferta de disciplinas regulares disponibilizadas como eletivas
#
#
#
#
# Para os ingressantes alunos de Engenharia de Computação cursando o 9º ou 10º semestres e para alunos de Ciência de Dados cursando o 8º semestre.
#
#
#
#
#
#
#
#
#
#
# 2º Semestre de 2025
#
#
# De 3 a 9 de julho de 2025, no
# Portal do Aluno
# , acesse o menu “Matrícula”, “Matrícula/Renovação”, verifique as disciplinas que você deverá cursar e confirme sua matrícula. As disciplinas disponíveis estão nos links abaixo:
#
#
#
#
#
#
# Oferta de disciplinas regulares
#
#
# As equivalências disponibilizadas são válidas para esta oferta, podendo sofrer alterações nos próximos semestres.
#
#
# O aluno deve conferir as disciplinas incluídas em sua matrícula e, em caso de qualquer divergência, deve entrar em contato com o SAE durante o período de matrículas.
#
#
#
#
#
#
#
#
#  Oferta de disciplinas regulares disponibilizadas como eletivas
#
#
#
#
# As eletivas estão previstas no 9º ou 10º semestres da matriz do curso de Engenharia de Computação, no 8º semestre na matriz de Ciência de Dados e no 9º e 10º semestres de Engenharia de Produção, neste último caso, a oferta disponível neste semestre é apenas para os alunos do 7º período que tiverem carga horária para antecipar disciplinas do 9º período.
#
#
#
#
#
#
#
#
#
#
#
#
# Tutorial de Renovação de Matrícula e Matrícula em DP
#
#
# Confira no tutorial abaixo como realizar a renovação da sua matrícula e como se matricular em disciplinas de Dependência (DP).
#
#
# Tutorial
#
# (divulgação de tutorial atualizado antes do período de matrículas)
#
#
#
#
#
#
#
#
#
# Instruções para matrícula
#
#
# Para saber mais sobre como proceder na sua matrícula, acesse nossos tutoriais:
#
#
#
#
# Novidades da matrícula
#
#
# Matrículas DP Regular
#
#
# Matrículas DP Inverno
#
#
#
#
# Acompanhe os períodos de matrícula pelo
# Calendário Acadêmico
#
#
#
#
#
#
#
#
#
#
# Aproveitamento de estudos
#
#
# Este documento
#  foi elaborado para auxiliá-lo a entender o processo de aproveitamento de estudos e também
#           para ajudá-lo a selecionar os documentos necessários para efetuar sua solicitação. Leia com atenção todas as dicas para garantir maior chance de aprovação do seu pedido!
#
#
# Ah! E temos também um tutorial
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Suas videoaulas na TV
#
#
# As videoaulas que você tem nas suas disciplinas e pode assistir no Youtube também são transmitidas pela
# UnivespTV
# !
#
#
# A sintonia é por meio dos canais digitais da multiprogramação da TV Cultura:
#
#
#
#
# Região Metropolitana de São Paulo
#  | Canal 2.2
#
#
# Região de Santos
#  | Canal 3.2
#
#
# Região de Campinas
#  | Canal 10.2
#
#
# Região de Ribeirão Preto
#  | Canal 4.2
#
#
# Região de São José dos Campos
#  | Canal 27.2
#
#
#
#
# Confira a a grade da programação especial dos cursos de férias no link abaixo:
#
#
#
#
#
#
# PROGRAMAÇÃO
#
#
#
#
#
#
#
#
#
#
# Colação de Grau
#
#
# A Colação de Grau ocorre em
# datas específicas
# , conforme o
# calendário acadêmico
# , após a conclusão dos
# componentes curriculares
#  por
#           parte do aluno, da verificação de toda a
# documentação entregue
#  à Univesp na matrícula e da regularidade no
# ENADE
# .
#
#
#
#
#
#
#
#
# ENADE
#
#
# Vai fazer Enade neste ano? Ou não sabe nem o que é Enade?
#
#
# Preparamos uma página com as perguntas mais frequentes sobre esse exame tão importante para você e para a Univesp.
#
#
# FAQ - 2025
#
#
# Salas Enade 2025:
#
#
# Você só terá acesso as salas se estiver inscrito no Enade 2025 pela Univesp.
#
#
#
#
# Letras
#
#
# Pedagogia
#
#
# Matemática
#
#
# Tecnologia em Processos Gerenciais
#
#
#
#
#
#
# FAQ - VERSÕES ANTERIORES
#
#
#
#
# FAQ - 2021
#
#
# FAQ - 2023
#
#
# FAQ - 2024
#
#
#
#
#
#
#
#
#
#
# Pós-Graduação
#
#
# Confira abaixo os regulamentos para o curso de pós-graduação em Educação Digital, com certificações em ação gestora para uma atuação inovadora e ação docente para uma atuação inovadora:
#
#
# Regulamento dos Cursos ou Programas de Pós-Graduação
# Lato Sensu
#  (Especialização)
#
#
# Regulamento do Trabalho de Conclusão de Curso (TCC) nos Cursos e Programas de Pós-Graduação
# Lato Sensu
#  da Univesp
#
#
#
#
# Inspire-se
# , acesse nosso
# repositório de trabalhos da pós-graduação
#  e veja os trabalhos anteriores de nossos alunos
#
#
#
#
#
#
#
#
# CPA
#
#
# A Comissão Própria de Avaliação (CPA) da UNIVESP, possui atuação autônoma e conduz o processo de avaliação interna da instituição, sistematizando os dados obtidos ao INEP. Para maiores informações sobre a CPA acesse o link:
# https://apps.univesp.br/academico/cpa/
# .
